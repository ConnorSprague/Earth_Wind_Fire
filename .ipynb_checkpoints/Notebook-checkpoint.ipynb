# %%
"""
Created on Fri Nov 22 14:22:07 2019

@author: fo628e
"""

import requests
from datetime import date

class date_formatter:
    today = date.today()

    def __init__(self):
        self.day_number = self.today.strftime("%d") #string, 22
        self.month = self.today.strftime("%B") #November
        self.basic_day = self.today.strftime("%B %d") #November 22
        self.shorthand_ordinal = 'empty'
        self.longhand_ordinal = 'empty'
        self.num_to_text = 'empty'
        

    def num2words(self):
        num = int(self.day_number)
        under_20 = ['Zero','One','Two','Three','Four','Five','Six','Seven','Eight','Nine',
                    'Ten','Eleven','Twelve','Thirteen','Fourteen','Fifteen','Sixteen','Seventeen','Eighteen','Nineteen']
        tens = ['Twenty','Thirty']
    
        if num < 20:
            self.num_to_text = under_20[num]
        else:
            self.num_to_text = tens[(int)(num/10)-2] + ('' if num%10==0 else ' ' + under_20[num%10])
            
        return(self.month+' '+self.num_to_text)
            
    def shorthand_date_ordinals(self):
        #date must be string
        #returns format; 22nd
        num = self.day_number
        last_digit = num[-1]
        suffix = ''
        if int(num) in range(11,19):
            suffix = 'th'
        elif last_digit=='1':
            suffix = 'st'
        elif last_digit=='2':
            suffix = 'nd'
        elif last_digit=='3':
            suffix = 'rd'
        else:
            suffix = 'th'
        self.shorthand_ordinal = num+suffix
        return(self.month+' '+self.shorthand_ordinal)
        
    def longhand_date_ordinals(self):
        #returns format: Twenty Second
        num = self.day_number
#        hold = self.num_to_text.split(' ')
#        if num 
#        non_zeroes = ['','first','second','third','fourth','fifth','sixth','seventh','eighth','ninth']
#        power = str(hold[0])
#        last_digit = num[-1]
#        if int(num) % 10 != 0:
#            self.longhand_ordinal = self.month+' '+power
        cheaters_translation = ['','first','second','third','fourth','fifth','sixth','seventh','eighth','ninth',
                       'tenth','eleventh','twelfth','thirteenth','fourteenth','fifteenth','sixteenth','seventeenth',
                       'eighteenth','nineteenth','twentieth','twenty-first','twenty-second','twenty-third','twenty-fourth',
                       'twenty-fifth','twenty-sixth','twenty-seventh','twenty-eighth','twenty-nineth','thirtieth', 'thirty-first']
        self.longhand_ordinal = self.month+' '+cheaters_translation[int(num)]
        return(self.longhand_ordinal)
    
    def my_dates(self):
        return([self.basic_day, self.num2words(),
                        self.shorthand_date_ordinals(),
                        self.longhand_date_ordinals()])

# %%
obj = date_formatter()
obj.basic_day
# Out:
# 'December 13'

# %% [markdown]
# NOTE: Need to build functionality to check current query results against previous day. If top results haven't changed, proceed to next n-top songs.
#
# NOTE: Only need to run query once, store/cache top 25 results for each query. Allow users to select from up to 5(?).

# %%
class musixmatch:
#API KEY
#ca6d099d26a175c667504ccdfac8489f

#API inputs
#q for query
#Most popular Songs about today   http://api.musixmatch.com/ws/1.1/apikey=ca6d099d26a175c667504ccdfac8489f&track.search?q={my dates}&s_track_rating=desc
#Most popular songs songs released today http://api.musixmatch.com/ws/1.1/track.search?f_track_release_group_first_release_date_min={YYYYMMDD}&f_track_release_group_first_release_date_max={YYYYMMDD}&s_track_rating=desc
    def __init__(self):
        self.date_object = date_formatter()
        self.date_array = self.date_object.my_dates()
        #request params
        self.sort_type = '&s_track_rating=desc'
        self.root_url = 'http://api.musixmatch.com/ws/1.1/'
        def get_api():
            api = ''
            return(api)
        
    def request(self,result_len,about_today=True, released_today=True):
        requests = []
        if about_today == True:
            query_type = 'track.search?q='
            requests.append(requests_helper(query_type))
            
        if released_today == True:
            api = get_api()
            query_date = datetime.strptime(my_string, "%Y%m%d")
            query_type = 'track.search?f_track_release_group_first_release_date_min={YYYYMMDD}&f_track_release_group_first_release_date_max={YYYYMMDD}'.format()
            requests_arr = [root_url+self.query_type+i+self.sort_type+api for i in self.date_array]
            requests.append(requests_arr)
            
        #format input dates into string
        def requests_helper(query_type):
            api = get_api()
            requests_arr = [root_url+self.query_type+i+self.sort_type+api for i in self.date_array]
            for req in requests_arr:
                response = requests.get(req)
                result = response.json()
                
            return(requests_arr)
        
        return()

# %%
objj = musixmatch()

# %%
class EWF_Result:
    
    def __init__(self):
        
    def top(self,count):
        
    def top_explicit(self, count):
        
    def top_instrumental(self, count):

# %%
import json
response = requests.get('http://api.musixmatch.com/ws/1.1/track.search?q=December 12th&s_track_rating=desc&apikey=ca6d099d26a175c667504ccdfac8489f')
#response.json()
r = response.json()
head = r['message']
body = head['body']
tracks = body['track_list']
tracks
# Out:
# [{'track': {'track_id': 83375847,
#    'track_name': 'Flowers In December (FM Broadcast The Metro Chicago 12th November 1994)',
#    'track_name_translation_list': [],
#    'track_rating': 20,
#    'commontrack_id': 46620258,
#    'instrumental': 0,
#    'explicit': 0,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 20797416,
#    'album_name': 'Ghost Highway',
#    'artist_id': 536,
#    'artist_name': 'Mazzy Star',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Mazzy-Star/Flowers-In-December-FM-Broadcast-The-Metro-Chicago-12th-November-1994?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Mazzy-Star/Flowers-In-December-FM-Broadcast-The-Metro-Chicago-12th-November-1994/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2017-05-21T09:57:23Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 20,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Alternative',
#        'music_genre_name_extended': 'Alternative',
#        'music_genre_vanity': 'Alternative'}}]}}},
#  {'track': {'track_id': 5371757,
#    'track_name': 'Microphone Mathematics',
#    'track_name_translation_list': [],
#    'track_rating': 16,
#    'commontrack_id': 929314,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 1,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 10668098,
#    'album_name': 'Microphone Mathematics',
#    'artist_id': 7370,
#    'artist_name': 'Quasimoto',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Quasimoto/Microphone-Mathematics?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Quasimoto/Microphone-Mathematics/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2012-06-28T01:45:05Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Hip Hop/Rap',
#        'music_genre_name_extended': 'Hip-Hop/Rap',
#        'music_genre_vanity': 'Hip-Hop-Rap'}},
#      {'music_genre': {'music_genre_id': 7,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Electronic',
#        'music_genre_name_extended': 'Electronic',
#        'music_genre_vanity': 'Electronic'}}]}}},
#  {'track': {'track_id': 17758157,
#    'track_name': 'Microphone Mathematics (remix)',
#    'track_name_translation_list': [],
#    'track_rating': 15,
#    'commontrack_id': 929317,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 1,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 10515449,
#    'album_name': "Hittin' Hooks",
#    'artist_id': 7370,
#    'artist_name': 'Quasimoto',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Quasimoto/Microphone-Mathematics-Remix?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Quasimoto/Microphone-Mathematics-Remix/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2012-08-16T10:50:04Z',
#    'primary_genres': {'music_genre_list': []}}},
#  {'track': {'track_id': 82025160,
#    'track_name': "While the Gettin's Good",
#    'track_name_translation_list': [],
#    'track_rating': 14,
#    'commontrack_id': 40827980,
#    'instrumental': 0,
#    'explicit': 0,
#    'has_lyrics': 1,
#    'has_subtitles': 1,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 19717137,
#    'album_name': 'County Line',
#    'artist_id': 405438,
#    'artist_name': 'High Valley',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/High-Valley/While-the-Gettin-s-Good?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/High-Valley/While-the-Gettin-s-Good/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2018-12-01T18:33:04Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 6,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Country',
#        'music_genre_name_extended': 'Country',
#        'music_genre_vanity': 'Country'}}]}}},
#  {'track': {'track_id': 1982969,
#    'track_name': 'On the Run',
#    'track_name_translation_list': [],
#    'track_rating': 13,
#    'commontrack_id': 818884,
#    'instrumental': 0,
#    'explicit': 0,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 1,
#    'album_id': 10381182,
#    'album_name': 'Straight Out the Jungle',
#    'artist_id': 6847,
#    'artist_name': 'Jungle Brothers',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Jungle-Brothers/On-the-Run?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Jungle-Brothers/On-the-Run/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2011-06-10T17:09:38Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Hip Hop/Rap',
#        'music_genre_name_extended': 'Hip-Hop/Rap',
#        'music_genre_vanity': 'Hip-Hop-Rap'}}]}}},
#  {'track': {'track_id': 17668202,
#    'track_name': "I Wouldn't Want To",
#    'track_name_translation_list': [],
#    'track_rating': 11,
#    'commontrack_id': 11034729,
#    'instrumental': 0,
#    'explicit': 0,
#    'has_lyrics': 1,
#    'has_subtitles': 1,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 14224237,
#    'album_name': 'Here We Are',
#    'artist_id': 13831488,
#    'artist_name': 'Citizens !',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Citizens-6/I-Wouldn-t-Want-To?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Citizens-6/I-Wouldn-t-Want-To/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2013-04-26T13:20:12Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 21,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Rock',
#        'music_genre_name_extended': 'Rock',
#        'music_genre_vanity': 'Rock'}},
#      {'music_genre': {'music_genre_id': 20,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Alternative',
#        'music_genre_name_extended': 'Alternative',
#        'music_genre_vanity': 'Alternative'}}]}}},
#  {'track': {'track_id': 52382120,
#    'track_name': '12Th Rising',
#    'track_name_translation_list': [],
#    'track_rating': 11,
#    'commontrack_id': 22659488,
#    'instrumental': 0,
#    'explicit': 0,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 13,
#    'album_id': 10297057,
#    'album_name': 'Vittra',
#    'artist_id': 7483,
#    'artist_name': 'Naglfar',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Naglfar/12-th-Rising?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Naglfar/12-th-Rising/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2015-02-22T16:10:48Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 21,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Rock',
#        'music_genre_name_extended': 'Rock',
#        'music_genre_vanity': 'Rock'}}]}}},
#  {'track': {'track_id': 3740224,
#    'track_name': 'Keep It Live',
#    'track_name_translation_list': [],
#    'track_rating': 11,
#    'commontrack_id': 7700421,
#    'instrumental': 0,
#    'explicit': 1,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 1,
#    'album_id': 10526718,
#    'album_name': 'Last Chance, No Breaks',
#    'artist_id': 144775,
#    'artist_name': 'Jamal',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Jamal/Keep-It-Live?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Jamal/Keep-It-Live/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2011-06-12T20:24:39Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 17,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Dance',
#        'music_genre_name_extended': 'Dance',
#        'music_genre_vanity': 'Dance'}},
#      {'music_genre': {'music_genre_id': 18,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Hip Hop/Rap',
#        'music_genre_name_extended': 'Hip-Hop/Rap',
#        'music_genre_vanity': 'Hip-Hop-Rap'}}]}}},
#  {'track': {'track_id': 87174935,
#    'track_name': 'London Calling - Live At The Forum 12th December 1991 (feat. Joe Strummer)',
#    'track_name_translation_list': [],
#    'track_rating': 1,
#    'commontrack_id': 49020723,
#    'instrumental': 0,
#    'explicit': 0,
#    'has_lyrics': 0,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 21083883,
#    'album_name': 'Just Look Them Straight In The Eye And Say... PogueMahone!!',
#    'artist_id': 9284,
#    'artist_name': 'The Pogues',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/The-Pogues/London-Calling-Live-At-The-Forum-12th-December-1991-feat-Joe-Strummer?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/The-Pogues/London-Calling-Live-At-The-Forum-12th-December-1991-feat-Joe-Strummer/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2015-12-23T13:57:38Z',
#    'primary_genres': {'music_genre_list': []}}},
#  {'track': {'track_id': 112896479,
#    'track_name': "Landin' Town",
#    'track_name_translation_list': [],
#    'track_rating': 1,
#    'commontrack_id': 31338647,
#    'instrumental': 0,
#    'explicit': 0,
#    'has_lyrics': 1,
#    'has_subtitles': 0,
#    'has_richsync': 0,
#    'num_favourite': 0,
#    'album_id': 23754429,
#    'album_name': 'The Story of Johnny Punish, Vol. I',
#    'artist_id': 26723517,
#    'artist_name': 'Johnny Punish',
#    'track_share_url': 'https://www.musixmatch.com/lyrics/Johnny-Punish/Landintown?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'track_edit_url': 'https://www.musixmatch.com/lyrics/Johnny-Punish/Landintown/edit?utm_source=application&utm_campaign=api&utm_medium=N%2FA%3A1409618754917',
#    'restricted': 0,
#    'updated_time': '2019-11-02T05:56:33Z',
#    'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 21,
#        'music_genre_parent_id': 34,
#        'music_genre_name': 'Rock',
#        'music_genre_name_extended': 'Rock',
#        'music_genre_vanity': 'Rock'}}]}}}]

# %%
def main():
    my_date = date_formatter()

    today_date_array = [my_date.basic_day, my_date.num2words(),
                        my_date.shorthand_date_ordinals(),
                        my_date.longhand_date_ordinals()]
    request_string = ''
    for i in today_date_array:
        print(i)
        request_string = request_string + i + ','
    request_string = request_string[:-1]
    dates = [i for i in today_date_array]
    print(dates)

# %%
main()
# Out:
# December 13
# December Thirteen
# December 13th
# December thirteenth
# ['December 13', 'December Thirteen', 'December 13th', 'December thirteenth']
